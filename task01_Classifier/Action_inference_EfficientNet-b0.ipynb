# %%
import os
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from torch.utils.data import DataLoader
from PIL import Image
import torch.nn.functional as F
import pandas as pd

# %%
image_size = 224
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 클래스 이름 정렬 방식 그대로 불러오기
train_path = "D:/Project/Action/processed_dataset/train"
class_names = datasets.ImageFolder(train_path).classes
num_classes = len(class_names)

# %%
weights = EfficientNet_B0_Weights.DEFAULT
model = efficientnet_b0(weights=weights)
model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
model.load_state_dict(torch.load("D:/Project/Action/efficientnet_b0_Action.pt"))
model = model.to(device)
model.eval()
# Out:
# C:\Users\roux\AppData\Local\Temp\ipykernel_22140\2925733464.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("D:/Project/Action/efficientnet_b0_Action.pt"))
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=12, bias=True)
#   )
# )

# %%
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5] * 3, [0.5] * 3)
])

# %%
inference_root = "D:/Project/Action/cat_frames2"
valid_exts = ('.jpg', '.jpeg', '.png')

image_paths = []
for dirpath, _, filenames in os.walk(inference_root):
    for fname in filenames:
        if fname.lower().endswith(valid_exts):
            image_paths.append(os.path.join(dirpath, fname))

# 추론 수행
print(f"Total images to infer: {len(image_paths)}\n")
# Out:
# Total images to infer: 300

# %%
results = []

for img_path in image_paths:
    try:
        image = Image.open(img_path).convert("RGB")
        input_tensor = transform(image).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(input_tensor)
            probs = F.softmax(output, dim=1)
            conf, predicted = torch.max(probs, 1)
            pred_class = class_names[predicted.item()]
            confidence = conf.item()

        relative_path = os.path.relpath(img_path, inference_root)
        results.append({
            "image_path": relative_path,
            "predicted_label": pred_class,
            "confidence": round(confidence, 4)
        })

        print(f"{relative_path} → {pred_class} ({confidence:.4f})")

    except Exception as e:
        print(f"[ERROR] {img_path} → {e}")
# Out:
# 목욕하는 고양이\frame_000.jpg → 머리를 들이대는 동작 (0.7798)
# 목욕하는 고양이\frame_001.jpg → 머리를 들이대는 동작 (0.9207)
# 목욕하는 고양이\frame_002.jpg → 머리를 들이대는 동작 (0.8671)
# 목욕하는 고양이\frame_003.jpg → 허리를 아치로 세우는 동작 (0.4720)
# 목욕하는 고양이\frame_004.jpg → 허리를 아치로 세우는 동작 (0.7366)
# 목욕하는 고양이\frame_005.jpg → 허리를 아치로 세우는 동작 (0.8154)
# 목욕하는 고양이\frame_006.jpg → 허리를 아치로 세우는 동작 (0.7633)
# 목욕하는 고양이\frame_007.jpg → 허리를 아치로 세우는 동작 (0.7475)
# 목욕하는 고양이\frame_008.jpg → 머리를 들이대는 동작 (0.4792)
# 목욕하는 고양이\frame_009.jpg → 머리를 들이대는 동작 (0.4891)
# 목욕하는 고양이\frame_010.jpg → 머리를 들이대는 동작 (0.7705)
# 목욕하는 고양이\frame_011.jpg → 머리를 들이대는 동작 (0.8968)
# 목욕하는 고양이\frame_012.jpg → 머리를 들이대는 동작 (0.7413)
# 목욕하는 고양이\frame_013.jpg → 머리를 들이대는 동작 (0.6807)
# 목욕하는 고양이\frame_014.jpg → 머리를 들이대는 동작 (0.5518)
# 목욕하는 고양이\frame_015.jpg → 머리를 들이대는 동작 (0.5680)
# 목욕하는 고양이\frame_016.jpg → 허리를 아치로 세우는 동작 (0.5411)
# 목욕하는 고양이\frame_017.jpg → 머리를 들이대는 동작 (0.6562)
# 목욕하는 고양이\frame_018.jpg → 머리를 들이대는 동작 (0.8631)
# 목욕하는 고양이\frame_019.jpg → 머리를 들이대는 동작 (0.8177)
# 목욕하는 고양이\frame_020.jpg → 머리를 들이대는 동작 (0.6189)
# 목욕하는 고양이\frame_021.jpg → 머리를 들이대는 동작 (0.7667)
# 목욕하는 고양이\frame_022.jpg → 머리를 들이대는 동작 (0.5903)
# 목욕하는 고양이\frame_023.jpg → 머리를 들이대는 동작 (0.7371)
# 목욕하는 고양이\frame_024.jpg → 머리를 들이대는 동작 (0.9226)
# 목욕하는 고양이\frame_025.jpg → 머리를 들이대는 동작 (0.8458)
# 목욕하는 고양이\frame_026.jpg → 머리를 들이대는 동작 (0.8209)
# 목욕하는 고양이\frame_027.jpg → 머리를 들이대는 동작 (0.6826)
# 목욕하는 고양이\frame_028.jpg → 머리를 들이대는 동작 (0.8232)
# 목욕하는 고양이\frame_029.jpg → 머리를 들이대는 동작 (0.8744)
# 목욕하는 고양이\frame_030.jpg → 팔을 뻗어 휘적거리는 동작 (0.4955)
# 목욕하는 고양이\frame_031.jpg → 납작 엎드리는 동작 (0.5529)
# 목욕하는 고양이\frame_032.jpg → 납작 엎드리는 동작 (0.6989)
# 목욕하는 고양이\frame_033.jpg → 머리를 들이대는 동작 (0.6350)
# 목욕하는 고양이\frame_034.jpg → 머리를 들이대는 동작 (0.6536)
# 목욕하는 고양이\frame_035.jpg → 머리를 들이대는 동작 (0.7621)
# 목욕하는 고양이\frame_036.jpg → 납작 엎드리는 동작 (0.4174)
# 목욕하는 고양이\frame_037.jpg → 머리를 들이대는 동작 (0.4715)
# 목욕하는 고양이\frame_038.jpg → 머리를 들이대는 동작 (0.5496)
# 목욕하는 고양이\frame_039.jpg → 납작 엎드리는 동작 (0.3759)
# 목욕하는 고양이\frame_040.jpg → 머리를 들이대는 동작 (0.6246)
# 목욕하는 고양이\frame_041.jpg → 납작 엎드리는 동작 (0.3913)
# 목욕하는 고양이\frame_042.jpg → 납작 엎드리는 동작 (0.4654)
# 목욕하는 고양이\frame_043.jpg → 머리를 들이대는 동작 (0.5318)
# 목욕하는 고양이\frame_044.jpg → 머리를 들이대는 동작 (0.5032)
# 목욕하는 고양이\frame_045.jpg → 머리를 들이대는 동작 (0.6878)
# 목욕하는 고양이\frame_046.jpg → 머리를 들이대는 동작 (0.5087)
# 목욕하는 고양이\frame_047.jpg → 머리를 들이대는 동작 (0.4755)
# 목욕하는 고양이\frame_048.jpg → 납작 엎드리는 동작 (0.3645)
# 목욕하는 고양이\frame_049.jpg → 납작 엎드리는 동작 (0.5113)
# 목욕하는 고양이\frame_050.jpg → 머리를 들이대는 동작 (0.7170)
# 목욕하는 고양이\frame_051.jpg → 머리를 들이대는 동작 (0.9403)
# 목욕하는 고양이\frame_052.jpg → 머리를 들이대는 동작 (0.9654)
# 목욕하는 고양이\frame_053.jpg → 머리를 들이대는 동작 (0.7493)
# 목욕하는 고양이\frame_054.jpg → 머리를 들이대는 동작 (0.6975)
# 목욕하는 고양이\frame_055.jpg → 머리를 들이대는 동작 (0.5414)
# 목욕하는 고양이\frame_056.jpg → 납작 엎드리는 동작 (0.8306)
# 목욕하는 고양이\frame_057.jpg → 납작 엎드리는 동작 (0.6874)
# 목욕하는 고양이\frame_058.jpg → 허리를 아치로 세우는 동작 (0.8819)
# 목욕하는 고양이\frame_059.jpg → 허리를 아치로 세우는 동작 (0.3677)
# 목욕하는 고양이\frame_060.jpg → 허리를 아치로 세우는 동작 (0.7143)
# 목욕하는 고양이\frame_061.jpg → 허리를 아치로 세우는 동작 (0.5406)
# 목욕하는 고양이\frame_062.jpg → 허리를 아치로 세우는 동작 (0.4988)
# 목욕하는 고양이\frame_063.jpg → 허리를 아치로 세우는 동작 (0.3980)
# 목욕하는 고양이\frame_064.jpg → 허리를 아치로 세우는 동작 (0.6936)
# 목욕하는 고양이\frame_065.jpg → 허리를 아치로 세우는 동작 (0.4455)
# 목욕하는 고양이\frame_066.jpg → 허리를 아치로 세우는 동작 (0.7356)
# 목욕하는 고양이\frame_067.jpg → 허리를 아치로 세우는 동작 (0.7344)
# 목욕하는 고양이\frame_068.jpg → 허리를 아치로 세우는 동작 (0.7462)
# 목욕하는 고양이\frame_069.jpg → 허리를 아치로 세우는 동작 (0.8520)
# 목욕하는 고양이\frame_070.jpg → 납작 엎드리는 동작 (0.7140)
# 목욕하는 고양이\frame_071.jpg → 허리를 아치로 세우는 동작 (0.6355)
# 목욕하는 고양이\frame_072.jpg → 허리를 아치로 세우는 동작 (0.4227)
# 목욕하는 고양이\frame_073.jpg → 허리를 아치로 세우는 동작 (0.8847)
# 목욕하는 고양이\frame_074.jpg → 납작 엎드리는 동작 (0.4419)
# 목욕하는 고양이\frame_075.jpg → 허리를 아치로 세우는 동작 (0.8261)
# 목욕하는 고양이\frame_076.jpg → 허리를 아치로 세우는 동작 (0.7601)
# 목욕하는 고양이\frame_077.jpg → 허리를 아치로 세우는 동작 (0.9618)
# 목욕하는 고양이\frame_078.jpg → 허리를 아치로 세우는 동작 (0.7571)
# 목욕하는 고양이\frame_079.jpg → 허리를 아치로 세우는 동작 (0.9448)
# 목욕하는 고양이\frame_080.jpg → 허리를 아치로 세우는 동작 (0.6953)
# 목욕하는 고양이\frame_081.jpg → 허리를 아치로 세우는 동작 (0.7729)
# 목욕하는 고양이\frame_082.jpg → 허리를 아치로 세우는 동작 (0.8386)
# 목욕하는 고양이\frame_083.jpg → 팔을 뻗어 휘적거리는 동작 (0.2712)
# 목욕하는 고양이\frame_084.jpg → 납작 엎드리는 동작 (0.4158)
# 목욕하는 고양이\frame_085.jpg → 납작 엎드리는 동작 (0.7139)
# 목욕하는 고양이\frame_086.jpg → 납작 엎드리는 동작 (0.7205)
# 목욕하는 고양이\frame_087.jpg → 납작 엎드리는 동작 (0.4890)
# 목욕하는 고양이\frame_088.jpg → 머리를 들이대는 동작 (0.5831)
# 목욕하는 고양이\frame_089.jpg → 머리를 들이대는 동작 (0.4616)
# 목욕하는 고양이\frame_090.jpg → 머리를 들이대는 동작 (0.7644)
# 목욕하는 고양이\frame_091.jpg → 머리를 들이대는 동작 (0.7323)
# 목욕하는 고양이\frame_092.jpg → 머리를 들이대는 동작 (0.8731)
# 목욕하는 고양이\frame_093.jpg → 머리를 들이대는 동작 (0.9449)
# 목욕하는 고양이\frame_094.jpg → 머리를 들이대는 동작 (0.9010)
# 목욕하는 고양이\frame_095.jpg → 머리를 들이대는 동작 (0.9692)
# 목욕하는 고양이\frame_096.jpg → 머리를 들이대는 동작 (0.9522)
# 목욕하는 고양이\frame_097.jpg → 머리를 들이대는 동작 (0.9524)
# 목욕하는 고양이\frame_098.jpg → 머리를 들이대는 동작 (0.9610)
# 목욕하는 고양이\frame_099.jpg → 머리를 들이대는 동작 (0.7691)
# 밥먹는 고양이\frame_000.jpg → 팔을 뻗어 휘적거리는 동작 (0.2951)
# 밥먹는 고양이\frame_001.jpg → 허리를 아치로 세우는 동작 (0.9725)
# 밥먹는 고양이\frame_002.jpg → 허리를 아치로 세우는 동작 (0.9040)
# 밥먹는 고양이\frame_003.jpg → 허리를 아치로 세우는 동작 (0.3845)
# 밥먹는 고양이\frame_004.jpg → 허리를 아치로 세우는 동작 (0.3735)
# 밥먹는 고양이\frame_005.jpg → 허리를 아치로 세우는 동작 (0.4126)
# 밥먹는 고양이\frame_006.jpg → 허리를 아치로 세우는 동작 (0.5233)
# 밥먹는 고양이\frame_007.jpg → 팔을 뻗어 휘적거리는 동작 (0.4327)
# 밥먹는 고양이\frame_008.jpg → 팔을 뻗어 휘적거리는 동작 (0.8310)
# 밥먹는 고양이\frame_009.jpg → 팔을 뻗어 휘적거리는 동작 (0.6038)
# 밥먹는 고양이\frame_010.jpg → 팔을 뻗어 휘적거리는 동작 (0.5926)
# 밥먹는 고양이\frame_011.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.3008)
# 밥먹는 고양이\frame_012.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7914)
# 밥먹는 고양이\frame_013.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5679)
# 밥먹는 고양이\frame_014.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6300)
# 밥먹는 고양이\frame_015.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9119)
# 밥먹는 고양이\frame_016.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8057)
# 밥먹는 고양이\frame_017.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7551)
# 밥먹는 고양이\frame_018.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8430)
# 밥먹는 고양이\frame_019.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8479)
# 밥먹는 고양이\frame_020.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8754)
# 밥먹는 고양이\frame_021.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8679)
# 밥먹는 고양이\frame_022.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5497)
# 밥먹는 고양이\frame_023.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6702)
# 밥먹는 고양이\frame_024.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6285)
# 밥먹는 고양이\frame_025.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5322)
# 밥먹는 고양이\frame_026.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6003)
# 밥먹는 고양이\frame_027.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7471)
# 밥먹는 고양이\frame_028.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7032)
# 밥먹는 고양이\frame_029.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6700)
# 밥먹는 고양이\frame_030.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5882)
# 밥먹는 고양이\frame_031.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9373)
# 밥먹는 고양이\frame_032.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5163)
# 밥먹는 고양이\frame_033.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6460)
# 밥먹는 고양이\frame_034.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6487)
# 밥먹는 고양이\frame_035.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6770)
# 밥먹는 고양이\frame_036.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7084)
# 밥먹는 고양이\frame_037.jpg → 납작 엎드리는 동작 (0.8137)
# 밥먹는 고양이\frame_038.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9354)
# 밥먹는 고양이\frame_039.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9525)
# 밥먹는 고양이\frame_040.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9807)
# 밥먹는 고양이\frame_041.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7708)
# 밥먹는 고양이\frame_042.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9923)
# 밥먹는 고양이\frame_043.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9184)
# 밥먹는 고양이\frame_044.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9043)
# 밥먹는 고양이\frame_045.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8581)
# 밥먹는 고양이\frame_046.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5952)
# 밥먹는 고양이\frame_047.jpg → 앞발로 꾹꾹 누르는 동작 (0.7070)
# 밥먹는 고양이\frame_048.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.4874)
# 밥먹는 고양이\frame_049.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5693)
# 밥먹는 고양이\frame_050.jpg → 앞발로 꾹꾹 누르는 동작 (0.4976)
# 밥먹는 고양이\frame_051.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7034)
# 밥먹는 고양이\frame_052.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.3776)
# 밥먹는 고양이\frame_053.jpg → 납작 엎드리는 동작 (0.2687)
# 밥먹는 고양이\frame_054.jpg → 머리를 들이대는 동작 (0.2517)
# 밥먹는 고양이\frame_055.jpg → 팔을 뻗어 휘적거리는 동작 (0.3092)
# 밥먹는 고양이\frame_056.jpg → 팔을 뻗어 휘적거리는 동작 (0.3238)
# 밥먹는 고양이\frame_057.jpg → 앞발로 꾹꾹 누르는 동작 (0.5324)
# 밥먹는 고양이\frame_058.jpg → 앞발로 꾹꾹 누르는 동작 (0.7736)
# 밥먹는 고양이\frame_059.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8732)
# 밥먹는 고양이\frame_060.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8821)
# 밥먹는 고양이\frame_061.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7532)
# 밥먹는 고양이\frame_062.jpg → 앞발로 꾹꾹 누르는 동작 (0.8082)
# 밥먹는 고양이\frame_063.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.4393)
# 밥먹는 고양이\frame_064.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8276)
# 밥먹는 고양이\frame_065.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6656)
# 밥먹는 고양이\frame_066.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.4985)
# 밥먹는 고양이\frame_067.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7239)
# 밥먹는 고양이\frame_068.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8329)
# 밥먹는 고양이\frame_069.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6964)
# 밥먹는 고양이\frame_070.jpg → 납작 엎드리는 동작 (0.4197)
# 밥먹는 고양이\frame_071.jpg → 납작 엎드리는 동작 (0.4770)
# 밥먹는 고양이\frame_072.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.3494)
# 밥먹는 고양이\frame_073.jpg → 납작 엎드리는 동작 (0.6207)
# 밥먹는 고양이\frame_074.jpg → 납작 엎드리는 동작 (0.5293)
# 밥먹는 고양이\frame_075.jpg → 앞발로 꾹꾹 누르는 동작 (0.4982)
# 밥먹는 고양이\frame_076.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7645)
# 밥먹는 고양이\frame_077.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6347)
# 밥먹는 고양이\frame_078.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9780)
# 밥먹는 고양이\frame_079.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9914)
# 밥먹는 고양이\frame_080.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9951)
# 밥먹는 고양이\frame_081.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9966)
# 밥먹는 고양이\frame_082.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9909)
# 밥먹는 고양이\frame_083.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9837)
# 밥먹는 고양이\frame_084.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.5995)
# 밥먹는 고양이\frame_085.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.7809)
# 밥먹는 고양이\frame_086.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9082)
# 밥먹는 고양이\frame_087.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8179)
# 밥먹는 고양이\frame_088.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8262)
# 밥먹는 고양이\frame_089.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8303)
# 밥먹는 고양이\frame_090.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.4373)
# 밥먹는 고양이\frame_091.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.8579)
# 밥먹는 고양이\frame_092.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9408)
# 밥먹는 고양이\frame_093.jpg → 납작 엎드리는 동작 (0.5926)
# 밥먹는 고양이\frame_094.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.6075)
# 밥먹는 고양이\frame_095.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9912)
# 밥먹는 고양이\frame_096.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9959)
# 밥먹는 고양이\frame_097.jpg → 발을 숨기고 웅크리고 앉는 동작 (0.9920)
# 밥먹는 고양이\frame_098.jpg → 팔을 뻗어 휘적거리는 동작 (0.5969)
# 밥먹는 고양이\frame_099.jpg → 팔을 뻗어 휘적거리는 동작 (0.5452)
# 보호자가 집에 온 고양이\frame_000.jpg → 허리를 아치로 세우는 동작 (0.7615)
# 보호자가 집에 온 고양이\frame_001.jpg → 걷거나 달리는 동작 (0.6848)
# 보호자가 집에 온 고양이\frame_002.jpg → 좌우로 뒹구는 동작 (0.8530)
# 보호자가 집에 온 고양이\frame_003.jpg → 납작 엎드리는 동작 (0.3812)
# 보호자가 집에 온 고양이\frame_004.jpg → 머리를 들이대는 동작 (0.2880)
# 보호자가 집에 온 고양이\frame_005.jpg → 좌우로 뒹구는 동작 (0.4615)
# 보호자가 집에 온 고양이\frame_006.jpg → 허리를 아치로 세우는 동작 (0.3856)
# 보호자가 집에 온 고양이\frame_007.jpg → 좌우로 뒹구는 동작 (0.3812)
# 보호자가 집에 온 고양이\frame_008.jpg → 좌우로 뒹구는 동작 (0.5227)
# 보호자가 집에 온 고양이\frame_009.jpg → 좌우로 뒹구는 동작 (0.5698)
# 보호자가 집에 온 고양이\frame_010.jpg → 배를 보여주는 동작 (0.5834)
# 보호자가 집에 온 고양이\frame_011.jpg → 좌우로 뒹구는 동작 (0.2957)
# 보호자가 집에 온 고양이\frame_012.jpg → 배를 보여주는 동작 (0.3898)
# 보호자가 집에 온 고양이\frame_013.jpg → 배를 보여주는 동작 (0.4531)
# 보호자가 집에 온 고양이\frame_014.jpg → 배를 보여주는 동작 (0.8063)
# 보호자가 집에 온 고양이\frame_015.jpg → 걷거나 달리는 동작 (0.9611)
# 보호자가 집에 온 고양이\frame_016.jpg → 걷거나 달리는 동작 (0.6384)
# 보호자가 집에 온 고양이\frame_017.jpg → 배를 보여주는 동작 (0.4531)
# 보호자가 집에 온 고양이\frame_018.jpg → 배를 보여주는 동작 (0.5897)
# 보호자가 집에 온 고양이\frame_019.jpg → 걷거나 달리는 동작 (0.8250)
# 보호자가 집에 온 고양이\frame_020.jpg → 걷거나 달리는 동작 (0.9576)
# 보호자가 집에 온 고양이\frame_021.jpg → 좌우로 뒹구는 동작 (0.3058)
# 보호자가 집에 온 고양이\frame_022.jpg → 배를 보여주는 동작 (0.6171)
# 보호자가 집에 온 고양이\frame_023.jpg → 납작 엎드리는 동작 (0.4432)
# 보호자가 집에 온 고양이\frame_024.jpg → 허리를 아치로 세우는 동작 (0.5388)
# 보호자가 집에 온 고양이\frame_025.jpg → 허리를 아치로 세우는 동작 (0.9891)
# 보호자가 집에 온 고양이\frame_026.jpg → 납작 엎드리는 동작 (0.4755)
# 보호자가 집에 온 고양이\frame_027.jpg → 납작 엎드리는 동작 (0.8954)
# 보호자가 집에 온 고양이\frame_028.jpg → 납작 엎드리는 동작 (0.7700)
# 보호자가 집에 온 고양이\frame_029.jpg → 납작 엎드리는 동작 (0.6957)
# 보호자가 집에 온 고양이\frame_030.jpg → 허리를 아치로 세우는 동작 (0.7264)
# 보호자가 집에 온 고양이\frame_031.jpg → 배를 보여주는 동작 (0.8692)
# 보호자가 집에 온 고양이\frame_032.jpg → 납작 엎드리는 동작 (0.3537)
# 보호자가 집에 온 고양이\frame_033.jpg → 배를 보여주는 동작 (0.5053)
# 보호자가 집에 온 고양이\frame_034.jpg → 배를 보여주는 동작 (0.6149)
# 보호자가 집에 온 고양이\frame_035.jpg → 납작 엎드리는 동작 (0.5607)
# 보호자가 집에 온 고양이\frame_036.jpg → 머리를 들이대는 동작 (0.7263)
# 보호자가 집에 온 고양이\frame_037.jpg → 허리를 아치로 세우는 동작 (0.2931)
# 보호자가 집에 온 고양이\frame_038.jpg → 옆으로 눕는 동작 (0.7323)
# 보호자가 집에 온 고양이\frame_039.jpg → 납작 엎드리는 동작 (0.6259)
# 보호자가 집에 온 고양이\frame_040.jpg → 납작 엎드리는 동작 (0.4990)
# 보호자가 집에 온 고양이\frame_041.jpg → 납작 엎드리는 동작 (0.9111)
# 보호자가 집에 온 고양이\frame_042.jpg → 납작 엎드리는 동작 (0.6121)
# 보호자가 집에 온 고양이\frame_043.jpg → 납작 엎드리는 동작 (0.9042)
# 보호자가 집에 온 고양이\frame_044.jpg → 납작 엎드리는 동작 (0.5237)
# 보호자가 집에 온 고양이\frame_045.jpg → 납작 엎드리는 동작 (0.8237)
# 보호자가 집에 온 고양이\frame_046.jpg → 머리를 들이대는 동작 (0.3150)
# 보호자가 집에 온 고양이\frame_047.jpg → 납작 엎드리는 동작 (0.3217)
# 보호자가 집에 온 고양이\frame_048.jpg → 납작 엎드리는 동작 (0.4027)
# 보호자가 집에 온 고양이\frame_049.jpg → 납작 엎드리는 동작 (0.5503)
# 보호자가 집에 온 고양이\frame_050.jpg → 납작 엎드리는 동작 (0.6184)
# 보호자가 집에 온 고양이\frame_051.jpg → 납작 엎드리는 동작 (0.8562)
# 보호자가 집에 온 고양이\frame_052.jpg → 납작 엎드리는 동작 (0.6898)
# 보호자가 집에 온 고양이\frame_053.jpg → 납작 엎드리는 동작 (0.9198)
# 보호자가 집에 온 고양이\frame_054.jpg → 납작 엎드리는 동작 (0.5288)
# 보호자가 집에 온 고양이\frame_055.jpg → 배를 보여주는 동작 (0.8076)
# 보호자가 집에 온 고양이\frame_056.jpg → 배를 보여주는 동작 (0.8089)
# 보호자가 집에 온 고양이\frame_057.jpg → 납작 엎드리는 동작 (0.5944)
# 보호자가 집에 온 고양이\frame_058.jpg → 납작 엎드리는 동작 (0.3756)
# 보호자가 집에 온 고양이\frame_059.jpg → 배를 보여주는 동작 (0.3837)
# 보호자가 집에 온 고양이\frame_060.jpg → 팔을 뻗어 휘적거리는 동작 (0.4889)
# 보호자가 집에 온 고양이\frame_061.jpg → 팔을 뻗어 휘적거리는 동작 (0.3426)
# 보호자가 집에 온 고양이\frame_062.jpg → 걷거나 달리는 동작 (0.4101)
# 보호자가 집에 온 고양이\frame_063.jpg → 배를 보여주는 동작 (0.2943)
# 보호자가 집에 온 고양이\frame_064.jpg → 배를 보여주는 동작 (0.4385)
# 보호자가 집에 온 고양이\frame_065.jpg → 팔을 뻗어 휘적거리는 동작 (0.4976)
# 보호자가 집에 온 고양이\frame_066.jpg → 팔을 뻗어 휘적거리는 동작 (0.3894)
# 보호자가 집에 온 고양이\frame_067.jpg → 배를 보여주는 동작 (0.4324)
# 보호자가 집에 온 고양이\frame_068.jpg → 걷거나 달리는 동작 (0.4175)
# 보호자가 집에 온 고양이\frame_069.jpg → 배를 보여주는 동작 (0.4029)
# 보호자가 집에 온 고양이\frame_070.jpg → 배를 보여주는 동작 (0.3324)
# 보호자가 집에 온 고양이\frame_071.jpg → 좌우로 뒹구는 동작 (0.4112)
# 보호자가 집에 온 고양이\frame_072.jpg → 좌우로 뒹구는 동작 (0.5957)
# 보호자가 집에 온 고양이\frame_073.jpg → 좌우로 뒹구는 동작 (0.5089)
# 보호자가 집에 온 고양이\frame_074.jpg → 배를 보여주는 동작 (0.6773)
# 보호자가 집에 온 고양이\frame_075.jpg → 배를 보여주는 동작 (0.4097)
# 보호자가 집에 온 고양이\frame_076.jpg → 배를 보여주는 동작 (0.9409)
# 보호자가 집에 온 고양이\frame_077.jpg → 좌우로 뒹구는 동작 (0.6213)
# 보호자가 집에 온 고양이\frame_078.jpg → 좌우로 뒹구는 동작 (0.4133)
# 보호자가 집에 온 고양이\frame_079.jpg → 배를 보여주는 동작 (0.7798)
# 보호자가 집에 온 고양이\frame_080.jpg → 배를 보여주는 동작 (0.9792)
# 보호자가 집에 온 고양이\frame_081.jpg → 배를 보여주는 동작 (0.9049)
# 보호자가 집에 온 고양이\frame_082.jpg → 배를 보여주는 동작 (0.5626)
# 보호자가 집에 온 고양이\frame_083.jpg → 배를 보여주는 동작 (0.8749)
# 보호자가 집에 온 고양이\frame_084.jpg → 배를 보여주는 동작 (0.9169)
# 보호자가 집에 온 고양이\frame_085.jpg → 배를 보여주는 동작 (0.6786)
# 보호자가 집에 온 고양이\frame_086.jpg → 배를 보여주는 동작 (0.8195)
# 보호자가 집에 온 고양이\frame_087.jpg → 허리를 아치로 세우는 동작 (0.4304)
# 보호자가 집에 온 고양이\frame_088.jpg → 허리를 아치로 세우는 동작 (0.4076)
# 보호자가 집에 온 고양이\frame_089.jpg → 좌우로 뒹구는 동작 (0.6189)
# 보호자가 집에 온 고양이\frame_090.jpg → 배를 보여주는 동작 (0.9289)
# 보호자가 집에 온 고양이\frame_091.jpg → 배를 보여주는 동작 (0.9972)
# 보호자가 집에 온 고양이\frame_092.jpg → 배를 보여주는 동작 (0.9588)
# 보호자가 집에 온 고양이\frame_093.jpg → 배를 보여주는 동작 (0.9922)
# 보호자가 집에 온 고양이\frame_094.jpg → 배를 보여주는 동작 (0.9972)
# 보호자가 집에 온 고양이\frame_095.jpg → 배를 보여주는 동작 (0.9987)
# 보호자가 집에 온 고양이\frame_096.jpg → 배를 보여주는 동작 (0.9996)
# 보호자가 집에 온 고양이\frame_097.jpg → 배를 보여주는 동작 (0.9990)
# 보호자가 집에 온 고양이\frame_098.jpg → 배를 보여주는 동작 (0.9983)
# 보호자가 집에 온 고양이\frame_099.jpg → 배를 보여주는 동작 (0.9998)

# %%
from collections import Counter

def smooth_labels(df, window_size=5):
    labels = df['predicted_label'].tolist()
    smoothed = []

    for i in range(len(labels)):
        start = max(0, i - window_size // 2)
        end = min(len(labels), i + window_size // 2 + 1)
        window = labels[start:end]
        majority_label = Counter(window).most_common(1)[0][0]
        smoothed.append(majority_label)

    df['smoothed_label'] = smoothed
    return df

# %%
def enforce_min_duration(labels, min_len=3):
    result = []
    prev = labels[0]
    count = 1
    for i in range(1, len(labels)):
        if labels[i] == prev:
            count += 1
        else:
            if count < min_len:
                result.extend([labels[i]] * count)
            else:
                result.extend([prev] * count)
            prev = labels[i]
            count = 1
    result.extend([prev] * count)
    return result

df['fixed_label_length_label'] = enforce_min_duration(df['smoothed_label'].tolist(), min_len=3)

# %%
df = pd.DataFrame(results, columns=["image_path", "predicted_label", "confidence"])
df = smooth_labels(df, window_size=7)
df['fixed_label_length_label'] = enforce_min_duration(df['smoothed_label'].tolist(), min_len=3)
df.to_csv("inference_results_smoothed_final.csv", index=False, encoding="utf-8-sig")
print("\nResults saved to 'inference_results.csv'")
# Out:
# Results saved to 'inference_results.csv'
